# %%
import pandas as pd



f_smiles=pd.read_csv("./datasets/ChangjiangRiver_check/779.csv")['SMILES'].values
tani=pd.read_csv("./datasets/ChangjiangRiver_check/outputs/779_778.csv")['ID2'].values

print()
